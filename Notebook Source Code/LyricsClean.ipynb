# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/lyricspkl", compression="zip")

# %%
df = df.reset_index()

# %%
df = df.replace('niggas', 'dudes', regex=True)
df = df.replace('nigga', 'dude', regex=True)
#df = df.drop("index")
df
# Out:
#       index  ...                                             LYRICS
# 0         0  ...  its only one, 03, i'm from grape street, where...
# 1         1  ...  you gonna make me put you in a suit and tie, s...
# 2         2  ...  we could kill it, yeah, we could, we could, we...
# 3         3  ...  yeah, you lil bitch ass dudes steady speaking ...
# 4         4  ...  x loaded up bro, never see me in the church, p...
# ...     ...  ...                                                ...
# 96809   728  ...  our fire will rise, ringmaster's eyes, funhous...
# 96810   729  ...  hey there killer, where you goin'?, i see you ...
# 96811   730  ...  life was shitty, can't call it, my karmas, bee...
# 96812   731  ...  somewhere in a lonely hotel room, there's a gu...
# 96813   732  ...  our fire will rise, ringmaster's eyes, funhous...
#
# [96814 rows x 6 columns]

# %%
df.describe()
# Out:
#         index  ...               LYRICS
# count   96814  ...                84617
# unique  23260  ...                81708
# top         0  ...  precious, precious.
# freq       24  ...                    4
#
# [4 rows x 6 columns]

# %%
df = df.dropna()
df.describe()
# Out:
#         index  ...               LYRICS
# count   84617  ...                84617
# unique  11078  ...                81708
# top         0  ...  precious, precious.
# freq       24  ...                    4
#
# [4 rows x 6 columns]

# %%
# import re
# import requests
# from time import sleep
# import random
# import pickle

# %%
# artist_genres = {}
# artist_urls = df['ARTIST_URL'].unique()
# def get_it(url):
#     try:
#         # always set a timeout when you connect to an external server
#         headers = { 
#           "apikey": "5a693e60-518e-11ea-97a6-af93e02394b4"
#         }
#         params = (
#           ("url", url),
#           ("premium","true"),
#         )
          
#         r = requests.get('https://app.zenscrape.com/api/v1/get', headers=headers, params=params);
#         data = r.text
#         x = re.search("(genre =)(\s\")[A-Za-z]*(\")", data)
#         if x is None:
#           print("Fricked it")
#           x = "Frick"
#         else:
#           x = x.group()
#         print(x)
#         artist_genres[url] = x
#         return 0
#     except socket.timeout:
#         # in a real world scenario you would probably do stuff if the
#         # socket goes into timeout
#         print("frick it")
# with PoolExecutor(max_workers=45) as executor:
#     for _ in executor.map(get_it, artist_urls):
#         pass

# output = open('myfile.pkl', 'wb')
# pickle.dump(artist_urls, output)
# output.close()

# %%
import pickle
genresDict = pickle.load(open('/content/drive/My Drive/genres.pkl', 'rb'))
genresDict
# Out:
# {'https://www.azlyrics.com/19/2gether.html': 'Frick',
#  'https://www.azlyrics.com/19/38special.html': 'Frick',
#  'https://www.azlyrics.com/19/5aftermidnight.html': 'genre = "pop"',
#  'https://www.azlyrics.com/19/3lau.html': 'genre = "pop"',
#  'https://www.azlyrics.com/19/03greedo.html': 'genre = "urban"',
#  'https://www.azlyrics.com/19/100blaze.html': 'genre = "urban"',
#  'https://www.azlyrics.com/19/36crazyfists.html': 'genre = "rock"',
#  'https://www.azlyrics.com/19/10cm.html': 'genre = "pop"',
#  'https://www.azlyrics.com/19/2ne1.html': 'genre = "pop"',
#  'https://www.azlyrics.com/19/411.html': 'genre = "urban"',
#  'https://www.azlyrics.com/19/2chainz.html': 'genre = "urban"',
#  'https://www.azlyrics.com/19/93feetofsmoke.html': 'genre = "urban"',
#  'https://www.azlyrics.com/19/5ive.html': 'genre = "pop"',
#  'https://www.azlyrics.com/19/1cuz.html': 'genre = "urban"',
#  'https://www.azlyrics.com/19/6ix9ine.html': 'genre = "urban"',
# ...

# %%
Keys = [x for x in genresDict if genresDict[x] == 'Frick']
Keys
# Out:
# ['https://www.azlyrics.com/19/2gether.html',
#  'https://www.azlyrics.com/19/38special.html',
#  'https://www.azlyrics.com/c/carter.html',
#  'https://www.azlyrics.com/a/alexhepburn.html',
#  'https://www.azlyrics.com/a/artofdying.html',
#  'https://www.azlyrics.com/a/alexparks.html',
#  'https://www.azlyrics.com/a/artgarfunkel.html',
#  'https://www.azlyrics.com/a/arinray.html',
#  'https://www.azlyrics.com/a/almost.html',
#  'https://www.azlyrics.com/r/rickastley.html',
#  'https://www.azlyrics.com/a/aubreyoday.html',
#  'https://www.azlyrics.com/a/aws.html',
#  'https://www.azlyrics.com/k/keithape.html',
#  'https://www.azlyrics.com/a/altj.html',
#  'https://www.azlyrics.com/a/americanauthors.html',
#  'https://www.azlyrics.com/a/alanparsonsproject.html',
#  'https://www.azlyrics.com/a/astro.html',
#  'https://www.azlyrics.com/a/amandastott.html',
#  'https://www.azlyrics.com/a/aqualung.html',
#  'https://www.azlyrics.com/a/alilohan.html',
# ...

# %%
import re
import requests
from time import sleep
import random
import pickle
from concurrent.futures import ThreadPoolExecutor as PoolExecutor
artist_genres = {}
artist_urls = Keys
def get_it(url):
    try:
        # always set a timeout when you connect to an external server
        headers = { 
          "apikey": "5a693e60-518e-11ea-97a6-af93e02394b4"
        }
        params = (
          ("url", url),
          ("premium","true"),
        )
          
        r = requests.get('https://app.zenscrape.com/api/v1/get', headers=headers, params=params);
        data = r.text
        x = re.search("(genre =)(\s\")[A-Za-z]*(\")", data)
        if x is None:
          print("Fricked it")
          x = "Frick"
        else:
          x = x.group()
        print(x)
        artist_genres[url] = x
        return 0
    except socket.timeout:
        # in a real world scenario you would probably do stuff if the
        # socket goes into timeout
        print("frick it")
with PoolExecutor(max_workers=3) as executor:
    for _ in executor.map(get_it, artist_urls):
        pass

output = open('moreGenres.pkl', 'wb')
pickle.dump(artist_urls, output)
output.close()
# Out:
# Fricked it
# Frick
# genre = "rock"
# genre = "rock"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "rock"
# genre = "urban"
# genre = "pop"
# genre = "pop"
# genre = "rock"
# genre = "urban"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# Fricked it
# Frick
# genre = "rock"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "urban"
# genre = "rock"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "rock"
# genre = "urban"
# genre = "urban"
# genre = "pop"
# genre = "urban"
# genre = "pop"
# genre = "urban"
# genre = "pop"
# genre = "pop"
# genre = "rock"
# genre = "pop"
# genre = "rock"
# genre = "rock"
# genre = "urban"
# genre = "rock"
# genre = "pop"
# genre = "urban"
# genre = "rock"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "urban"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "pop"
# genre = "urban"
# ...

# %%
output = open('moreGenres.pkl', 'wb')
pickle.dump(artist_genres, output)
output.close()

# %%
genresDict2 = pickle.load(open('moreGenres.pkl', 'rb'))
genresDict2
# Out:
# {' fire': 'Frick',
#  ' han var dold': 'Frick',
#  ' party': 'Frick',
#  ' see the evil inside': 'Frick',
#  ' the adolescent': 'Frick',
#  ' uno zombie non muore mai': 'Frick',
#  ' whispers in the powder room': 'Frick',
#  ' yo yo this is the best birthday ever!': 'Frick',
# ...

# %%
Keys = [x for x in genresDict2 if genresDict2[x] == 'Frick']
Keys
# Out:
# ['https://www.azlyrics.com/c/carter.html',
#  'https://www.azlyrics.com/a/ali-as.html',
#  'https://www.azlyrics.com/b/boysetsfire.html',
#  'https://www.azlyrics.com/i/isleybrothers.html',
#  'https://www.azlyrics.com/e/elevationworship.html',
#  ' han var dold',
#  ' party',
#  ' the adolescent',
#  ' see the evil inside',
#  ' yo yo this is the best birthday ever!',
# ...

# %%
genresDictFull = {}
for key in genresDict:
  if genresDict[key] != "Frick":
    genresDictFull[key] = genresDict[key]
for key in genresDict2:
  if genresDict2[key] != "Frick":
    genresDictFull[key] = genresDict2[key]

# %%
len(genresDictFull)
# Out:
# 4276

# %%
df.describe()
# Out:
#         index  ...               LYRICS
# count   84617  ...                84617
# unique  11078  ...                81708
# top         0  ...  precious, precious.
# freq       24  ...                    4
#
# [4 rows x 6 columns]

# %%
import numpy as np
df["GENRE"] = np.nan
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       index  ... GENRE
# 0         0  ...   NaN
# 1         1  ...   NaN
# 2         2  ...   NaN
# 3         3  ...   NaN
# 4         4  ...   NaN
# ...     ...  ...   ...
# 96809   728  ...   NaN
# 96810   729  ...   NaN
# 96811   730  ...   NaN
# 96812   731  ...   NaN
# 96813   732  ...   NaN
#
# [84617 rows x 7 columns]

# %%
for index, row in df.iterrows():
  if row['ARTIST_URL'] in genresDictFull:
    df.loc[index, "GENRE"] = genresDictFull[row['ARTIST_URL']]
    if(index%300 == 0):
      print(index)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 0
# 300
# 600
# 900
# 1200
# 1500
# 1800
# 2100
# 2400
# 2700
# 3000
# 3300
# 3600
# 3900
# 4200
# 4500
# 4800
# 5100
# 5400
# 5700
# 6000
# 6300
# 6600
# 6900
# 7200
# 7500
# 7800
# 8100
# 8400
# 8700
# 9000
# 9300
# 9600
# 9900
# 10200
# 10500
# 10800
# 11100
# 11400
# 11700
# 12000
# 12300
# 12600
# ...

# %%
df
# Out:
#       index  ...            GENRE
# 0         0  ...  genre = "urban"
# 1         1  ...  genre = "urban"
# 2         2  ...  genre = "urban"
# 3         3  ...  genre = "urban"
# 4         4  ...  genre = "urban"
# ...     ...  ...              ...
# 96809   728  ...  genre = "urban"
# 96810   729  ...  genre = "urban"
# 96811   730  ...  genre = "urban"
# 96812   731  ...  genre = "urban"
# 96813   732  ...  genre = "urban"
#
# [84617 rows x 7 columns]

# %%
df['GENRE'] = df['GENRE'].str.lstrip('genre = "')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['GENRE'] = df['GENRE'].str.rstrip('"')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       index  ...  GENRE
# 0         0  ...  urban
# 1         1  ...  urban
# 2         2  ...  urban
# 3         3  ...  urban
# 4         4  ...  urban
# ...     ...  ...    ...
# 96809   728  ...  urban
# 96810   729  ...  urban
# 96811   730  ...  urban
# 96812   731  ...  urban
# 96813   732  ...  urban
#
# [84617 rows x 7 columns]

# %%
df = df.dropna()
df = df.reset_index()
df
# Out:
#        level_0 index  ...                                             LYRICS  GENRE
# 0            0     0  ...  its only one, 03, i'm from grape street, where...  urban
# 1            1     1  ...  you gonna make me put you in a suit and tie, s...  urban
# 2            2     2  ...  we could kill it, yeah, we could, we could, we...  urban
# 3            3     3  ...  yeah, you lil bitch ass dudes steady speaking ...  urban
# 4            4     4  ...  x loaded up bro, never see me in the church, p...  urban
# ...        ...   ...  ...                                                ...    ...
# 84327    96809   728  ...  our fire will rise, ringmaster's eyes, funhous...  urban
# 84328    96810   729  ...  hey there killer, where you goin'?, i see you ...  urban
# 84329    96811   730  ...  life was shitty, can't call it, my karmas, bee...  urban
# 84330    96812   731  ...  somewhere in a lonely hotel room, there's a gu...  urban
# ...

# %%
df["GENRE"] = df["GENRE"].replace({"ock": "rock", "Pop": "pop"})

# %%
df["GENRE"].unique()
# Out:
# array(['urban', 'pop', 'rock', ''], dtype=object)

# %%
df = df.drop(['level_0', 'index'], axis=1)

# %%
df.to_pickle("lyrics_cleaned_zip.pkl", compression="zip")

# %%
df["GENRE"].unique()
# Out:
# array(['urban', 'pop', 'rock', ''], dtype=object)
